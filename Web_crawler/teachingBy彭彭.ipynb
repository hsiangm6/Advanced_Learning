# %%
#Web crawler 基本
#抓取ppt電影版的html原始碼
# https://www.youtube.com/watch?v=9Z9xKWfNo7k&list=RDCMUCguZS-y7codLSt6vpkVdnKg&index=1
import urllib.request as req

url="https://www.ptt.cc/bbs/movie/index.html"
#建立request物件，再利用物件打開網址，傅家request headers的資訊
request=req.Request(url, headers={ 
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"
})
with req.urlopen(request) as response:
    data=response.read().decode("utf-8")


# 解析原始碼，取得每篇文章的標題
import bs4
root=bs4.BeautifulSoup(data, "html.parser") #讓beautifulsoup4協助我們解析html格式
print(root.title)
print(root.title.string)
post_title=root.find("div", class_="title") #find會幫助尋找其中一個class="title"的div標籤
print(post_title)
print(post_title.a.string, "\n")
post_titles=root.find_all("div", class_="title") #find會幫助尋找所有class="title"的div標籤，如果條件是id則id="title"
for title in post_titles:
    if title.a != None: #如果標題包含a標籤(沒有被刪除)
        print(title.a.string)
# Out:
# <title>看板 movie 文章列表 - 批踢踢實業坊</title>
# 看板 movie 文章列表 - 批踢踢實業坊
# <div class="title">
# <a href="/bbs/movie/M.1682087226.A.1C2.html">[新聞] 亞瑞阿斯特恐怖三連拍 不想被定型</a>
# </div>
# [新聞] 亞瑞阿斯特恐怖三連拍 不想被定型
#
# [新聞] 亞瑞阿斯特恐怖三連拍 不想被定型
# [請益] 龍與地下城 or 阿凡達2 4DX
# [情報] 《沙贊2》賣輸《魔比斯》
# [新聞] 漫威用替身就好 歐森:親自演特技浪費時間
# [普好雷] 鈴芽之旅是否該二刷
# [問片] 我只記得一個場景 求救大神
# [好雷] Ghosted (真愛搞失蹤) Apple TV的電影
# [新聞] 黑人之亂？小美人魚、埃及豔后通通變黑人
# [好雷] 逐夢大海 True Spirit （Netflix）
# Re: [討論] 是漫威殞落/星際3沒人氣/還是缺宣傳?
# [新聞] 車庫娛樂告贏觸電網！控「著作權排除
# [情報] 岩井俊二新片是音樂電影！廣瀨鈴、黑木華回歸演出
# [好雷] 超級瑪利歐兄弟電影版
# [公告] 電影板板規 2022/12/5

# %%
#web crawler- cookie(連線時放在request headers中送出)
#追蹤下一頁網頁連結，連續抓取頁面
#抓取ppt八卦版的html
# https://www.youtube.com/watch?v=BEA7F9ExiPY&list=RDCMUCguZS-y7codLSt6vpkVdnKg&index=2
import urllib.request as req

def getData(url):
    #建立request物件，再利用物件打開網址，傅家request headers的資訊
    request=req.Request(url, headers={ 
        #cookie在network的其中一檔案中的request header
        "cookie":"over18=1", #加入cookie告訴網頁我有over18
        #user-agent在network的其中一檔案中的request header
        "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"
    })
    with req.urlopen(request) as response:
        data=response.read().decode("utf-8")


    # 解析原始碼，取得每篇文章的標題
    import bs4
    root=bs4.BeautifulSoup(data, "html.parser") #讓beautifulsoup4協助我們解析html
    post_titles=root.find_all("div", class_="title") #find會幫助尋找所有class="title"的div標籤，如果條件是id則id="title"
    for title in post_titles:
        if title.a != None: #如果標題包含a標籤(沒有被刪除)
            print(title.a.string)

    #抓取上一頁的網址
    nextLink=root.find("a", string="‹ 上頁") #找到內文是‹ 上頁 的a標籤
    return nextLink["href"] #中括號內是屬性名稱

#抓取一個頁面的標題
pageURL="https://www.ptt.cc/bbs/Gossiping/index.html"
count=0
while count<3: #抓取3頁的標題
    pageURL="https://www.ptt.cc"+getData(pageURL)
    count+=1
# Out:
# [問卦] 外國人說台灣治安好 484 30分看50分?
# Re: [問卦] 中國山東淄博，這座城市真的佩服！
# [問卦] 還好光陽機車廣告不是在火鍋店約會
# [問卦] 有沒有台灣投手身材的八卦
# [問卦] 以後還會出現什麼奇葩的殺人法？
# [新聞] 「廖老大」挑戰滿州拉力賽喊刺激 狂讚屏
# [新聞] 《就業服務法》修法三讀通過 移工失
# Re: [問卦] 黑道流氓為啥能有投票權?他們會投的都...
# [公告] 八卦板板規(2023.03.01)
# [協尋] 4/12 08:00台中-五權西路三段 行車紀錄器
# Fw: [寶寶] 妙兒園負責人原址新開「詠欣」托嬰中心
# [爆卦] 柬埔寨政府控告半島電視台
# [爆卦] 內湖托育中心虐嬰（發錢）
# [問卦] 台積電總裁該換人了吧
# [問卦] 其實熱湯才真的是終極武器吧??
# [問卦] 房屋成本只能佔收入的三成？
# [問卦] 請問機車的任意第三人責任險
# [問卦] 女生是不是不能穿puma這牌子的東西
# [問卦] 臺中還適合人住嗎？
# [問卦] chatGPT工讀生會不會過勞死啊
# [問卦] 死後不是消失吧？
# Re: [新聞] 台灣學生神回覆「我們不一樣」中國學生氣
# [問卦] 越宣導越多人被騙的八卦
# [問卦] 金城武是不是過氣了？ㄏ
# [問卦] 公家機關一堆小主管養情婦是真的嗎????
# [問卦] 妳各位Netflix都訂多久了？
# [問卦] 假設赤壁被韓國人翻拍會怎樣？
# Re: [問卦] 為啥網路上越多路權團體，交通越差？
# [問卦] 社會敗壞 學校老師該怎麼教學生？
# [問卦] 早餐店蛋價什麼時候調降回來呀？
# [問卦] 我們一直走向民主為何言論自由被限縮？
# [問卦] 會不會湯根本就還沒滾
# [新聞] 快訊／鬆口了！被國民黨徵召會說Yes, I
# [問卦] 貓貓氣噗噗怎辦？？？？
# [問卦] 是不是很多店家不喜歡收大鈔？
# [問卦] 回帳跟自願繳薪水一樣嗎？
# Re: [問卦] 為啥酒店小姐,有小孩還要做八大?
# [問卦] 以前總統府的防備有這麼森嚴？
# Re: [新聞] 「班班吃鳳梨」成20校營養午餐?陳吉仲喊
# Re: [問卦] 台灣越來越像墨西哥是我的錯覺嗎
# [新聞] 邰智源衝台積電花園「完全沒人！」員工噴
# [問卦] 為啥現在只剩下北極玄天上帝？
# [問卦] 吸菸室的台灣大媽視訊吵死日本人？
# Re: [問卦] 我們的教育哪一步走錯 才導致8+9滿街跑
# Re: [新聞] 秦剛：兩岸同屬一中 也是台灣的現狀
# [問卦] 火鍋業者該自肅停業一天了吧
# [問卦] 台灣愈來愈像日本是我的錯覺嗎
# [問卦] 社會大學有教綜合格鬥嗎？
# [問卦] 大家比較支持憲兵擴編還是保二擴編???
# Re: [新聞] 「班班吃鳳梨」成20校營養午餐?陳吉仲喊
# [問卦] 劍聖的劍二十三跟無名天劍誰強
# Re: [問卦] 我們的教育哪一步走錯 才導致8+9滿街跑
# [新聞] 21歲正妹公然露下體「廣場上自慰」！　影

# %%
#Web crawler-AJAX/XHR(網頁前端的JS技術) 使用AJAX的網頁運作會發送多次請求到網頁伺服器，
#   第二次請求才會取得資料並產生網頁畫面
#抓取kkday.com的首頁文章列表，認出網站運作模式，找出真正能抓到資料的網址
# AJAX網頁在載入的時候會有停頓只出現框架，而且在原始碼中搜尋文章標題是搜尋不到的
# https://www.youtube.com/watch?v=IMOUf4BYTG8&list=RDCMUCguZS-y7codLSt6vpkVdnKg&index=4

import urllib.request as req
# 要找出真正的網址，要從network篩選XHR，找到其中一檔案的preview裡包含文章標題，
#       此檔案的header裡的url和user-agent才是真正的
url="https://www.kkday.com/zh-tw/home/ajax_get_homepage_setting?csrf_token_name=9515f0a591f5d0ea01d0e66c4abe3042"
#建立request物件，再利用物件打開網址，傅家request headers的資訊
request=req.Request(url, headers={ 
    # ":authority": "www.kkday.com",
    # ":method": "GET",
    # ":path": "/zh-tw/home/ajax_get_homepage_setting?csrf_token_name=b41b7a3a600f7ad308c2550626ca598d",
    # ":scheme": "https",
    "accept": "application/json, text/javascript, */*; q=0.01",
    # "accept-encoding": "gzip, deflate, br", #服务器传过来压缩格式gzip的文件:https://blog.csdn.net/the_jack/article/details/117633533
    "accept-language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6",
    "cookie": "csrf_cookie_name=b41b7a3a600f7ad308c2550626ca598d; KKWEB=a%3A4%3A%7Bs%3A10%3A%22session_id%22%3Bs%3A32%3A%226f617f923e196ea5f9ed3546700531e5%22%3Bs%3A7%3A%22channel%22%3Bs%3A5%3A%22GUEST%22%3Bs%3A13%3A%22last_activity%22%3Bi%3A1679500895%3Bs%3A9%3A%22user_data%22%3Bs%3A0%3A%22%22%3B%7Da284f8a5c35885de8531f540c0ecb68b; country_lang=zh-tw; currency=TWD; KKUD=6f617f923e196ea5f9ed3546700531e5; _ga_RJJY5WQFKP=GS1.1.1679500790.1.1.1679500895.60.0.0; mp_b8150a8ddf736c19fdc0f146b9ffac24_mixpanel=%7B%22distinct_id%22%3A%20%2218709ed9a9715c-027a1835f92a2c-26031851-1fa400-18709ed9a98ce6%22%2C%22%24device_id%22%3A%20%2218709ed9a9715c-027a1835f92a2c-26031851-1fa400-18709ed9a98ce6%22%2C%22%24search_engine%22%3A%20%22google%22%2C%22%24initial_referrer%22%3A%20%22https%3A%2F%2Fwww.google.com%2F%22%2C%22%24initial_referring_domain%22%3A%20%22www.google.com%22%2C%22Platform%22%3A%20%22www.kkday.com%22%2C%22LoginChannel%22%3A%20%22NO%22%2C%22DisplayCurrency%22%3A%20%22TWD%22%2C%22DisplayLang%22%3A%20%22zh-tw%22%2C%22DisplayCountry%22%3A%20%22TW%22%2C%22Cid%22%3A%20%22%22%2C%22Ud1%22%3A%20%22expired%22%2C%22Ud2%22%3A%20%22expired%22%2C%22Tier%22%3A%20null%2C%22MemberUuid%22%3A%20%22%22%2C%22Kkud%22%3A%20%226f617f923e196ea5f9ed3546700531e5%22%2C%22Display%20Currency%22%3A%20%22TWD%22%2C%22Display%20Lang%22%3A%20%22zh-tw%22%2C%22Display%20Country%22%3A%20%22TW%22%2C%22CID%22%3A%20%22expired%22%2C%22KKUD%22%3A%20%226f617f923e196ea5f9ed3546700531e5%22%7D; _dd_s=rum=2&id=43932604-96b0-4d09-8982-b228c30843a5&created=1679500895560&expire=1679501795561; _gcl_au=1.1.1863623845.1679500896",
    "referer": "https://www.kkday.com/zh-tw",
    # "sec-ch-device-memory": "8",
    # "sec-ch-ua": ""Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"",
    # "sec-ch-ua-arch": ""x86"",
    # "sec-ch-ua-full-version-list": ""Google Chrome";v="111.0.5563.65", "Not(A:Brand";v="8.0.0.0", "Chromium";v="111.0.5563.65"",
    # "sec-ch-ua-mobile": "?0",
    # "sec-ch-ua-platform": ""Windows"",
    "sec-fetch-dest":"empty",
    # "sec-fetch-mode": "cors",
    # "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36",
    "x-requested-with": "XMLHttpRequest"
})
with req.urlopen(request) as response:
    data=response.read().decode("utf-8") #根據觀察，取得的資料是JSON格式


# 解析JSON格式，取得每篇文章的標題
import json
data=json.loads(data) #把原始的JSON資料解析成字典/列表的表示形式
#取得JSON資料中的文章標題
posts=data["data"]["homepage_product_group"]
for key in posts:
    print(key["title"])
# Out:
# 為你推薦
# 聽說山上下雪了✨日賞桐花夜賞螢💕
# 五星飯店住宿快閃🔥 MOTEL新上架加碼贈全家咖啡🥤
# 猜你喜歡
# 花火節開跑🎇澎湖必玩特色體驗💦
# 📛獨家優惠📛巴黎迪士尼樂園🏰
# 日本美食🇯🇵米其林摘星🌟
# 出發濟州島🏝春日海岸風光💕
# 光露營就好了🏕帶著行李出發🚗
# 全民普發6000元💰加碼國旅優惠❗
# 全台樂園最酷玩伴大集合🧸
# 全球樂園歡樂無限🎢
# 安心出遊讓你更放鬆👉跟著評鑑優良夥伴出去玩🛩

# %%
#Web crawler - request data(請求附帶的資料)
import urllib.request as req
import json
#建立連線網址
url="https://medium.com/_/graphql"
#建立一個Request物件，附上request headers, request data的資訊
#requestData from Request Payload
requestData={"operationName":"CuratedHomeFeedModuleQuery","variables":{"paging":{"from":"10","limit":10}},"query":"query CuratedHomeFeedModuleQuery($paging: PagingOptions!) {\n  staffPicksFeed(input: {paging: $paging}) {\n    items {\n      ...CuratedHomeFeedItems_homeFeedItems\n      __typename\n    }\n    pagingInfo {\n      next {\n        page\n        limit\n        from\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment CuratedHomeFeedItems_homeFeedItems on HomeFeedItem {\n  __typename\n  post {\n    id\n    title\n    ...HomeFeedItem_post\n    __typename\n  }\n}\n\nfragment HomeFeedItem_post on Post {\n  __typename\n  id\n  title\n  firstPublishedAt\n  mediumUrl\n  collection {\n    id\n    name\n    domain\n    logo {\n      id\n      __typename\n    }\n    __typename\n  }\n  creator {\n    id\n    name\n    username\n    imageId\n    mediumMemberAt\n    __typename\n  }\n  previewImage {\n    id\n    __typename\n  }\n  previewContent {\n    subtitle\n    __typename\n  }\n  readingTime\n  tags {\n    ...TopicPill_tag\n    __typename\n  }\n  ...BookmarkButton_post\n  ...OverflowMenuButtonWithNegativeSignal_post\n  ...PostPresentationTracker_post\n  ...PostPreviewAvatar_post\n  ...Star_post\n}\n\nfragment TopicPill_tag on Tag {\n  __typename\n  id\n  displayTitle\n  normalizedTagSlug\n}\n\nfragment BookmarkButton_post on Post {\n  visibility\n  ...SusiClickable_post\n  ...AddToCatalogBookmarkButton_post\n  __typename\n  id\n}\n\nfragment SusiClickable_post on Post {\n  id\n  mediumUrl\n  ...SusiContainer_post\n  __typename\n}\n\nfragment SusiContainer_post on Post {\n  id\n  __typename\n}\n\nfragment AddToCatalogBookmarkButton_post on Post {\n  ...AddToCatalogBase_post\n  __typename\n  id\n}\n\nfragment AddToCatalogBase_post on Post {\n  id\n  __typename\n}\n\nfragment OverflowMenuButtonWithNegativeSignal_post on Post {\n  id\n  visibility\n  ...OverflowMenuWithNegativeSignal_post\n  __typename\n}\n\nfragment OverflowMenuWithNegativeSignal_post on Post {\n  id\n  creator {\n    id\n    __typename\n  }\n  collection {\n    id\n    __typename\n  }\n  ...OverflowMenuItemUndoClaps_post\n  __typename\n}\n\nfragment OverflowMenuItemUndoClaps_post on Post {\n  id\n  clapCount\n  ...ClapMutation_post\n  __typename\n}\n\nfragment ClapMutation_post on Post {\n  __typename\n  id\n  clapCount\n  ...MultiVoteCount_post\n}\n\nfragment MultiVoteCount_post on Post {\n  id\n  ...PostVotersNetwork_post\n  __typename\n}\n\nfragment PostVotersNetwork_post on Post {\n  id\n  voterCount\n  recommenders {\n    name\n    __typename\n  }\n  __typename\n}\n\nfragment PostPresentationTracker_post on Post {\n  id\n  visibility\n  previewContent {\n    isFullContent\n    __typename\n  }\n  collection {\n    id\n    slug\n    __typename\n  }\n  __typename\n}\n\nfragment PostPreviewAvatar_post on Post {\n  __typename\n  id\n  collection {\n    id\n    name\n    ...CollectionAvatar_collection\n    __typename\n  }\n  creator {\n    id\n    username\n    name\n    ...UserAvatar_user\n    ...userUrl_user\n    ...useIsVerifiedBookAuthor_user\n    __typename\n  }\n}\n\nfragment CollectionAvatar_collection on Collection {\n  name\n  avatar {\n    id\n    __typename\n  }\n  ...collectionUrl_collection\n  __typename\n  id\n}\n\nfragment collectionUrl_collection on Collection {\n  id\n  domain\n  slug\n  __typename\n}\n\nfragment UserAvatar_user on User {\n  __typename\n  id\n  imageId\n  mediumMemberAt\n  name\n  username\n  ...userUrl_user\n}\n\nfragment userUrl_user on User {\n  __typename\n  id\n  customDomainState {\n    live {\n      domain\n      __typename\n    }\n    __typename\n  }\n  hasSubdomain\n  username\n}\n\nfragment useIsVerifiedBookAuthor_user on User {\n  verifications {\n    isBookAuthor\n    __typename\n  }\n  __typename\n  id\n}\n\nfragment Star_post on Post {\n  id\n  creator {\n    id\n    __typename\n  }\n  __typename\n}\n"}
request=req.Request(url, headers={ 
    "content-type": "application/json",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36",
},data=json.dumps(requestData).encode("utf-8")) #data=請求的額外資料, data=json.dumps(requestData).encode("utf-8") #json.dump把資料變成字串，再用utf-8編碼
#發出請求
with req.urlopen(request) as response:
    result=response.read().decode("utf-8") #根據觀察，取得的資料是JSON格式
#解析json格式的資料，取得每篇文章的標題
result=json.loads(result) #將字串格式轉換為字典格式
# print(result)
# print(result["data"]["staffPicksFeed"]["items"][0]["post"]["title"]) #試著印出第一篇文章的標題
items=result["data"]["staffPicksFeed"]["items"]
for item in items:  #印出10篇文章標題
    print(item["post"]["title"])
# Out:
# The TikTok Teens Go To Washington
# What it takes to make 165 years of journalism available online
# The Unquenchable Thirst to Be a Noun
# Soul Food: Is Delicious Damn The Lies.
# The Dog and the Dinosaur
# Why poetry matters
# Report from a Relationship
# What We’re Reading: Dungeons & Dragons & AI
# I’ll Be 50 This Year — It’s Sobering
# AI and the American Smile

# %%
#python 檔案的存取、讀取

# %%
#Web crawler 基本
#抓取ppt電影版的html原始碼
# https://www.youtube.com/watch?v=9Z9xKWfNo7k&list=RDCMUCguZS-y7codLSt6vpkVdnKg&index=1
import urllib.request as req

url="https://kkasum1.lofter.com/post/1ff5c40c_2b4e83490"
#建立request物件，再利用物件打開網址，傅家request headers的資訊
request=req.Request(url, headers={ 
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"
})
with req.urlopen(request) as response:
    data=response.read().decode("utf-8")


# 解析原始碼，取得每篇文章的標題
import bs4
root=bs4.BeautifulSoup(data, "html.parser") #讓beautifulsoup4協助我們解析html格式
# print(root.title)
print(root.title.string)
texts=root.find_all("div", class_="text") #find會幫助尋找其中一個class="title"的div標籤
print(texts)

# print(p)
# for text in texts:
#     print(texts)


    

# print(post_title.a.string, "\n")
# post_titles=root.find_all("div", class_="title") #find會幫助尋找其中一個class="title"的div標籤，如果條件是id則id="title"
# for title in post_titles:
#     if title.a != None: #如果標題包含a標籤(沒有被刪除)
#         print(title.a.string)
# Out:
# 【原创女主×Ren】1-拉瓦
# [<div class="text"></div>, <div class="text">
# <h2><a href="https://kkasum1.lofter.com/post/1ff5c40c_2b4e83490">【原创女主×Ren】1</a></h2>
# <p>//三流通灵师五流古刀法传人×财阀继承人</p>
# <p>//谢刀×Ren</p>
# <p>ps：完全乱来的意淫之作</p>
# <p>　　</p>
# <p>　　1</p>
# <p>　　“Phupha Komolpetch，”</p>
# <p>　　与其说是高中生，不如说已经初具一个男人的模样了，坐在深红色皮椅里，身上的豹纹大衣比泰国的闷热天儿还要逼人，像一头锋芒毕露不知收敛为何物的狮子。</p>
# <p>　　“高三（1）班，背景清白的好学生……”</p>
# <p>　　他看着被摁在水里的男学生，却压根没把对方放在眼里，嘴里念着那学生的资料，每一个咬词都泄露了他的轻蔑。</p>
# <p>　　</p>
# <p>　　他走近Phupha，俯身的动作里也尽是掌控别人的漫不经心。</p>
# <p>　　“也就是说你把这些视频备份了是吗？”他意味不明地顿了下，故作姿态：“那……就不可能消失了…”</p>
# <p>　　</p>
# <p>　　那四个人实在显眼，拿着电脑的男人穿着黑皮衣，他对着电话那头说了什么，接着视频便在Phupha面前的手机显示屏上凭空消失。</p>
# <p>　　</p>
# <p>　　Phupha坚毅的表情维持不住，“Thyme！你怎么敢！”</p>
# <p>　　</p>
# <p>　　Thyme乐于欣赏phupha绝望愤怒的神色，连惊讶都演的拙劣，“啊？怎么消失了？”</p>
# <p>　　</p>
# <p>　　——太坏了，仿佛天生没有同理心的坏种。</p>
# <p>　　</p>
# <p>　　Thyme似笑非笑，这个占尽好风水的浑蛋少爷轻而易举地说：“Phupha，对我们来说，本身就没什么难事啊。”</p>
# <p>　　</p>
# <p>　　众人欢呼高歌，纸团垃圾承载着平时压抑着的躁动向中央投去，拳打脚踢伴着欢呼声，毫无节制地挥洒年轻的能量和恶意，不知道的还以为是什么邪教现场。</p>
# <p>　　</p>
# <p>　　Phupha惊惧之下，怀着破釜沉舟的愤怒地蹭起身给了Thyme一拳，四周一静。</p>
# <p>　　</p>
# <p>　　“啊…”Thyme摸了摸脸，笑得又疯又狠，把phupha按住。</p>
# <p>　　</p>
# <p>　　接着是更张狂的喧嚣声，M.J悠哉游哉跟Kavin打着赌。</p>
# <p>　　赌需要几分钟Phupha就会被Thyme干翻。</p>
# <p>　　好不嚣张。</p>
# <p>　　</p>
# <p>　　Phupha年轻的脊骨被人踹翻在地，他拼尽全力的反击与不平愤懑都只是一个笑话，这个年轻的灵魂在悲鸣。</p>
# <p>　　</p>
# <p>　　混乱中却有一人仿佛终于厌烦这扰人清净的狂热，Ren对眼前的暴行视而不见，那是一种漠然的傲慢，站起身回首望一眼台上各色看客。</p>
# <p>　　有人狂喜趁乱行恶，有人麻木不仁，有人面露怜悯。</p>
# <p>　　</p>
# <p>　　在最高处一个纤细的身影先他一步转身离去，留下浮光掠影的一道身影，她背后形状怪异的盒子随她动作发出哐啷的一声响，却没有惊动任何人。</p>
# <p>　　如同她来时亦无声无息。</p>
# <p>　　让人怀疑那里是否真的有人来过。</p>
# <p>　　</p>
# <p>　　Ren顿了下脚步，微微拧眉。</p>
# <p>　　终究是什么也没望进眼里，他将一切狂热的泛着恶臭的氛围都扔在身后，踏上台阶离开。</p>
# <p>　　</p>
# <p>　　_</p>
# <p>　　</p>
# <p>　　“哇啊啊啊啊——！！！”</p>
# <p>　　</p>
# <p>　　“这个学校到底是怎么了！！！？？？”</p>
# <p>　　</p>
# <p>　　声音中气十足，震得鸟惊四飞。</p>
# <p>　　</p>
# <p>　　谢刀垂死病中惊坐起，人还没太清醒，非常暴躁地手拄着草地循着声音去找。</p>
# <p>　　谁！！！</p>
# <p>　　他。娘。的。</p>
# <p>　　是谁！！</p>
# <p>　　</p>
# <p>　　她半睁着眼往上看。</p>
# <p>　　</p>
# <p>　　“balabala外壳，balabala问题balabala……”</p>
# <p>　　那姑娘穿着绿色校服，正站在天台边上一通狂轰滥炸。</p>
# <p>　　“…这就是优秀的学生吗！！笨蛋笨蛋balabala F4 balabala……”</p>
# <p>　　</p>
# <p>　　醒了。这下完全醒了。</p>
# <p>　　</p>
# <p>　　“真是疯——了——！！”</p>
# <p>　　</p>
# <p>　　谢刀：“……”</p>
# <p>　　这穿透力，内息深厚，适合练武啊。</p>
# <p>　　谢刀的泰语学得不太行，一点点听不懂。有点迷茫，更多的是无可宣泄的暴躁。</p>
# <p>　　“艹。”</p>
# <p>　　人被吵醒就会暴躁，暴躁就会干坏事，谢刀垮起张批脸，打开盒子提起里面的刀往草地中间走。</p>
# <p>　　她抬起头往上看。</p>
# <p>　　“那谁。”</p>
# <p>　　</p>
# <p>　　Gorya：“啊啊啊啊啊啊啊啊啊啊啊啊！！”</p>
# <p>　　</p>
# <p>　　“……”</p>
# <p>　　很好。她完全没听见的。</p>
# <p>　　谢刀放弃喊麦，扎了个马步，抡起大刀往旁边可怜的树干上砍。</p>
# <p>　　“哐——”</p>
# <p>　　</p>
# <p>　　“哐哐——”</p>
# <p>　　</p>
# <p>　　Gorya：“……！？”</p>
# <p>　　</p>
# <p>　　谢刀运气，挥刀如砍柴，“哐哐哐——！！”</p>
# <p>　　</p>
# <p>　　Gorya倒仰：“！！！”</p>
# <p>　　</p>
# <p>　　那可怜的装饰性绿植一般的枝丫哪经得起她这粗糙的对待，叶子哗啦哗啦直往下掉，很快就摇摇欲坠了，凋残几片绿叶。</p>
# <p>　　画面一度非常之凶狠。</p>
# <p>　　谢刀长长吐出一口浊气，站直了遥遥跟目瞪口呆的少女对上了视线。</p>
# <p>　　</p>
# <p>　　四周一寂。</p>
# <p>　　</p>
# <p>　　“啊！！”Gorya先注意到的是那把巨大的黑漆漆的刀，然后是身量娇小的少女一错不错地瞪着自己，吓了她一跳，下意识问：“你是谁？？”</p>
# <p>　　</p>
# <p>　　我是你爹。</p>
# <p>　　</p>
# <p>　　谢刀把这话在嘴里无声地嚼了两遍，差不多冷静了，她拍掉身上的树叶，没再管天台上的少女，任其在上面扒着栏杆好奇地盯着她看。</p>
# <p>　　“你砍了学校的树？不会被罚吗？有监控的！”</p>
# <p>　　谢刀默了一下。</p>
# <p>　　忘记现代都市哪哪都有监控了。</p>
# <p>　　</p>
# <p>　　Gorya觉得这个少女看起来不太友好，那种不友好会让她吓一跳但又不至于敬而远之，她莫名地感到好奇和兴奋，“啊！我刚刚是不是吵到你了？”</p>
# <p>　　一通大喊过后理智回笼，Gorya后知后觉感到丢人，讷讷地，“对不起啊，我以为没人了。”</p>
# <p>　　算了。</p>
# <p>　　谢刀微有动容，但她拒绝回答。</p>
# <p>　　等她把刀放回盒子再抬头，天台上的少女已经不见了，取而代之的是一个着浅色衬衫的少年，头发有点乱，个儿高的惊人，双手随意撑在栏杆上，朝她投来没什么情绪的一瞥。</p>
# <p>　　</p>
# <p>　　对视两秒。</p>
# <p>　　</p>
# <p>　　两人或许都对对方这突兀的出现感到好奇，非常巧合的是，两个人都是对方成长经历里不会见到的那一类，同时他们都有非常人的素质，非常坦然地互相打量。</p>
# <p>　　看着那少年通身的气度，衬衫褶儿都写着很贵。</p>
# <p>　　谢刀想起了前两天看过的资料，回想起那闪瞎眼的身价忍不住眯了眯眼，“Renrawin Aira？”</p>
# <p>　　轻声吐出这个名字。</p>
# <p>　　</p>
# <p>　　“嗯？”</p>
# <p>　　少年是听不见她在说什么的，但他突然弯腰朝她勾了下脑袋，似乎要听听她在说什么一样，头发有点乱糟糟的，站在风中吹的更乱了些。</p>
# <p>　　看起来很像毛茸茸的犬科生物，让人非常想给他捋一捋。</p>
# <p>　　</p>
# <p>　　谢刀：“…啧。”</p>
# <p>　　她别开脸，将一言不发贯彻到底，背起刀盒往外走。</p>
# <p>　　</p>
# </div>]
